# %% [markdown]
# # Basic python

# %% [markdown]
# #### Welcome

# %%
# Single line comments start with a number symbol.

# %% [markdown]
# ### Strings

# %%
# Strings are created with " or '
"This is a string."

# %%
'This is also a string.'

# %%
type("This is a string?")

# %%
# You can find the length of a string
len("This is a string")  # => 16

# %% [markdown]
# ### Numbers

# %%
5

# %%
n = 5 # n is integer

# %%
type(5)

# %%
m = 5.0

# %%
type(m)

# %% [markdown]
# ### Simple Math

# %%
# Math is what you would expect
a = 1 + 1   
b = 8 - 1   
c = 10 * 2 
d = 35 / 5

# %%
print('a=',a)
print('b=',b)
print('c=',c)
print('d=',d)

# %%
5 // 3       # => 1

# %%
-5 // 3      # => -2

# %%
5.0 // 3.0   # => 1.0 # works on floats too

# %%
# The result of division is always a float
10 / 3

# %%
type(10/3)

# %% [markdown]
# ### Boolean Operators
#
# Note: "and" and "or" are case-sensitive

# %%
True and False  # => False

# %%
False or True   # => True

# %%
type(True)

# %%
# Equality is ==
1 == 1  # => Trueb

# %%
2 == 1  # => False

# %%
# Inequality is !=
1 != 1  # => False

# %%
2 != 1  # => True

# %% [markdown]
# ### **=** is   Assignment Operator

# %%
# There are no declarations, only assignments.
some_var = 5

# %%
some_var

# %%
# Accessing a previously unassigned variable is an exception.
some_unknown_var

# %%
a = 8 # the value 8 gets assigned to a

# %%
print('a =',a)
print('type of a =', type(a))

# %%
a = 9 # a is overwritten by 9
print('so now a = ',a)

# %%
a = 'hello' # a is overwritten by 9
print('so now a = ',a)
print('type of a =', type(a))

# %% [markdown]
# ### Lists

# %%
# Lists store sequences
li = []

# %%
type(li)

# %%
# You can start with a prefilled list
other_li = [4, 5, 6]

# %%
other_li

# %%
# Add stuff to the end of a list with append
li.append(1)    # li is now [1]
li.append(2)    # li is now [1, 2]
li.append(4)    # li is now [1, 2, 4]
li.append(3)    # li is now [1, 2, 4, 3]

# %%
# Remove from the end with pop
li.pop()

# %%
li.append(3)

# %%
li

# %%
# Looking out of bounds is an IndexError
li[4]  # Raises an IndexError

# %% [markdown]
# #### Slices
# You can look at ranges with slice syntax.
#
#
# **Note:The start index is included, the end index is not**

# %%
li[1:3]   # Return list from index 1 to 3 => [2, 4]
li[2:]    # Return list starting from index 2 => [4, 3]
li[:3]    # Return list from beginning until index 3  => [1, 2, 4]
li[::2]   # Return list selecting every second entry => [1, 4]
li[::-1]  # Return list in reverse order => [3, 4, 2, 1]

# Use any combination of these to make advanced slices
# li[start:end:step]

# %%
# Remove arbitrary elements from a list with "del"
del li[2]

# %%
li

# %%
# Remove first occurrence of a value
li.remove(2)  # li is now [1, 3]

# %%
li.remove(2)  # Raises a ValueError as 2 is not in the list

# %%
# Check for existence in a list with "in"
1 in li

# %%
# Examine the length with "len()"
len(li)

# %% [markdown]
# ### Dictionaries

# %%
# Dictionaries store mappings from keys to values
empty_dict = {}
type(empty_dict)

# %%
# Here is a prefilled dictionary
filled_dict = {"one": 1, "two": 2, "three": 3}

# %%
# Note keys for dictionaries have to be immutable types. This is to ensure that
# Immutable types include ints, floats, strings, tuples(you will learn this soon).
invalid_dict = {[1,2,3]: "123"}

# %%
valid_dict = {2:[1,2,3]}   # Values can be of any type, however.

# %%
# Look up values with []
filled_dict["one"]

# %%
# Get all keys as an iterable with "keys()". We need to wrap the call in list()
# to turn it into a list. We'll talk about those later.
list(filled_dict.keys())

# %%
list(filled_dict.values())

# %%
# Check for existence of keys in a dictionary with "in"
"one" in filled_dict

# %%
1 in filled_dict

# %%
# Looking up a non-existing key is a KeyError
filled_dict["four"]

# %%
# Adding to a dictionary
filled_dict["four"] = 4
filled_dict

# %%
# Remove keys from a dictionary with del
del filled_dict["one"]

# %%
filled_dict

# %% [markdown]
# ### If else

# %%
# if and else allows you to run some code conditionally. 
# The condition should return True or False

# %%
some_var = 5

# %%
# Here is an if statement. Indentation is significant in Python!
if some_var > 10:
    print("some_var is totally bigger than 10.")
elif some_var < 10:    # This elif clause is optional.
    print("some_var is smaller than 10.")
else:                  # This is optional too.
    print("some_var is indeed 10.")

# %%
# try writing some if else on your own

# %% [markdown]
# ### Loops

# %%
#range(number)" returns an iterable of numbers from zero to the given number
for i in range(4):
    print(i)

# %%
#range(lower, upper, step)" returns an iterable of numbers
#from the lower number to the upper number, while incrementing
#by step. If step is not indicated, the default value is 1.
for i in range(4, 8, 2):
    print(i)

# %%
#For loops iterate over lists
mammals = ["dog", "cat", "mouse"]

for animal in mammals :
    print(animal + " is a mammal")

# %%
# for loops iterate over dict KEYS as well
filled_dict = {"one": 1, "two": 2, "three": 3}

for element in filled_dict :
    print("key is: " + element)

# %%
# Can you print all the values in filled_dict?

# %%
x = 0
while x < 4:
    print(x)
    x += 1

# %% [markdown]
# ### Functions

# %%
# Use "def" to create new functions
def add(x, y):
    print("x is {} and y is {}".format(x, y))
    return x + y  # Return values with a return statement

# %%
# Calling functions with parameters
add(5, 6)  # => prints out "x is 5 and y is 6" and returns 11

# %%
# try writing some functions on your own
